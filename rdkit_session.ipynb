# %% [markdown]
# # RDKit Session
#
# Session working through RDKit introduction.

# %%
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
import pandas as pd
import numpy as np

# %%
# Create simple molecule
m = Chem.MolFromSmiles('c1Cccc1')
m
